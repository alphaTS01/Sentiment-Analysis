# %%
import os
import pandas as pd
import requests

# Load the CSV file
csv_path = "/kaggle/input/sentiment-analysis/reference.csv"  # Change to your actual file path
df = pd.read_csv(csv_path)

# Create a directory for saving images
save_dir = "/kaggle/working/train_images"
os.makedirs(save_dir, exist_ok=True)

# Ensure required columns exist
if "image_url" not in df.columns or "image_name" not in df.columns:
    raise ValueError("CSV file must contain 'image_url' and 'image_name' columns.")

# List to track successfully downloaded image indices
downloaded_indices = []

# Function to download images sequentially
for _, row in df.iterrows():
    img_url = row["image_url"]
    img_name = row["image_name"]
    img_path = os.path.join(save_dir, img_name)

    try:
        response = requests.get(img_url, stream=True, timeout=10)
        if response.status_code == 200:
            with open(img_path, "wb") as img_file:
                img_file.write(response.content)
            print(f"Downloaded: {img_name}")

            # Extract image number (assuming format "image_number.extension")
            image_number = os.path.splitext(img_name)[0].split("_")[1]
            downloaded_indices.append(image_number)

        else:
            print(f"Failed to download: {img_url} (Status Code: {response.status_code})")

    except Exception as e:
        print(f"Error downloading {img_url}: {e}")

# Save successfully downloaded indices to a CSV file
success_log_path = "downloaded_images.csv"
pd.DataFrame({"downloaded_index": downloaded_indices}).to_csv(success_log_path, index=False)

print(f"All downloads completed! Successfully downloaded indices saved to {success_log_path}.")
# Out:
# Downloaded: image_1.jpg
# Downloaded: image_2.jpeg
# Downloaded: image_3.JPG
# Error downloading https://pics.conservativememes.com/10-year-challenge-sweet-dee-edition-40184302.png: HTTPSConnectionPool(host='pics.conservativememes.com', port=443): Max retries exceeded with url: /10-year-challenge-sweet-dee-edition-40184302.png (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a942efda3e0>: Failed to resolve 'pics.conservativememes.com' ([Errno -2] Name or service not known)"))
# Error downloading https://pics.me.me/10-year-challenge-with-no-filter-47-hilarious-10-year-42949168.png: HTTPSConnectionPool(host='pics.me.me', port=443): Max retries exceeded with url: /10-year-challenge-with-no-filter-47-hilarious-10-year-42949168.png (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a942efdb370>: Failed to resolve 'pics.me.me' ([Errno -2] Name or service not known)"))
# Error downloading https://img.memecdn.com/10-years-challenge-about-humanity_o_7260933.jpg: HTTPSConnectionPool(host='img.memecdn.com', port=443): Max retries exceeded with url: /10-years-challenge-about-humanity_o_7260933.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a942efdbbe0>: Failed to resolve 'img.memecdn.com' ([Errno -2] Name or service not known)"))
# Error downloading https://pics.me.me/10-years-challenge-is-it-af-1945-1955-wow-such-40196337.png: HTTPSConnectionPool(host='pics.me.me', port=443): Max retries exceeded with url: /10-years-challenge-is-it-af-1945-1955-wow-such-40196337.png (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a942eda03d0>: Failed to resolve 'pics.me.me' ([Errno -2] Name or service not known)"))
# Downloaded: image_8.jpg
# Downloaded: image_9.jpg
# Downloaded: image_10.png
# Error downloading https://ahseeit.com/tamil/king-include/uploads/2019/01/fb_img_1547706013873-7619029167.jpg: HTTPSConnectionPool(host='ahseeit.com', port=443): Max retries exceeded with url: /tamil/king-include/uploads/2019/01/fb_img_1547706013873-7619029167.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7a942efd9c60>: Failed to establish a new connection: [Errno 111] Connection refused'))
#
Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a942efd9ed0>: Failed to resolve 'memebomb.net' ([Errno -2] Name or service not known)"))
# Failed to download: http://www.gifbooster.com/wp-content/uploads/655/barney-stinson-meme_28_paused.jpg (Status Code: 404)
# Downloaded: image_126.jpg
# Downloaded: image_127.jpg
# Downloaded: image_128.jpg
# Error downloading https://img.memecdn.com/barney-stinson_o_5068093.jpg: HTTPSConnectionPool(host='img.memecdn.com', port=443): Max retries exceeded with url: /barney-stinson_o_5068093.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a942ed90250>: Failed to resolve 'img.memecdn.com' ([Errno -2] Name or service not known)"))
# Downloaded: image_130.png
# Error downloading https://img.memecdn.com/barney-stinson-with-the-smurfs_o_1945087.jpg: HTTPSConnectionPool(host='img.memecdn.com', port=443): Max retries exceeded with url: /barney-stinson-with-the-smurfs_o_1945087.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a942efdb7f0>: Failed to resolve 'img.memecdn.com' ([Errno -2] Name or service not known)"))
# Error downloading https://pics.astrologymemes.com/breaking-sources-say-okc-will-sign-barney-stinson-to-a-11053787.png: HTTPSConnectionPool(host='pics.astrologymemes.com', port=443): Max retries exceeded with url: /breaking-sources-say-okc-will-sign-barney-stinson-to-a-11053787.png (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a943d1949d0>: Failed to resolve 'pics.astrologymemes.com' ([Errno -2] Name or service not known)"))
# Downloaded: image_133.jpg
# Downloaded: image_134.jpg
# Downloaded: image_135.jpg
# Downloaded: image_136.jpg
# Downloaded: image_137.jpg
# Downloaded: image_138.jpg
# Failed to download: https://wanna-joke.com/wp-content/uploads/2013/12/funny-picture-barney-friendship-over.jpg (Status Code: 403)
# Error downloading http://blackdia.net/wp-content/uploads/2018/08/funny-quotes-barney-stinson-best-of-barney-himym-meme-here-for-more-fun-quotes-himym-of-funny-quotes-barney-stinson.jpg: HTTPConnectionPool(host='blackdia.net', port=80): Max retries exceeded with url: /wp-content/uploads/2018/08/funny-quotes-barney-stinson-best-of-barney-himym-meme-here-for-more-fun-quotes-himym-of-funny-quotes-barney-stinson.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7a942ed91210>: Failed to resolve 'blackdia.net' ([Errno -2] Name or service not known)"))
# Downloaded: image_141.jpg
# Downloaded: image_142.jpg
# Error downloading https://pics.esmemes.com/its-gonna-be-legend-wait-for-it-i-hope-11000280.png: HTTPSConnectionPool(host='pics.esmemes.com', port=443): Max retries exceeded with url: /its-gonna-be-legend-wait-for-it-i-hope-11000280.png (Caused by SSLError(SSLError(1, '[SSL: TLSV1_UNRECOGNIZED_NAME] tlsv1 unrecognized name (_ssl.c:1007)')))
# Error downloading https://pics.awwmemes.com/i-was-fourseasons-ona-show-called-doogie-houser-md-13591242.png: HTTPSConnectionPool(host='pics.awwmemes.com', port=443): Max retries exceeded with url: /i-was-fourseasons-ona-show-called-doogie-houser-md-13591242.png (Caused by SSLError(SSLError(1, '[SSL: TLSV1_UNRECOGNIZED_NAME] tlsv1 unrecognized name (_ssl.c:1007)')))
# Error downloading https://pics.me.me/lied-to-over-200-girls-stillbelieveseverythinghis-mothertold-him-when-he-11143811.png: HTTPSConnectionPool(host='pics.me.me', port=443): Max retries exceeded with url: /lied-to-over-200-girls-stillbelieveseverythinghis-mothertold-him-when-he-11143811.png (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x
# Error downloading https://pics.awwmemes.com/whaaaaat-when-someone-says-they-hate-barney-stinson-https-t-co-eta01glcwb-34329864.png: HTTPSConnectionPool(host='pics.awwmemes.com', port=443): Max retries exceeded with url: /whaaaaat-when-someone-says-they-hate-barney-stinson-https-t-co-eta01glcwb-34329864.png (Caused by SSLError(SSLError(1, '[SSL: TLSV1_UNRECOGNIZED_NAME] tlsv1 unrecognized name (_ssl.c:1007)')))
# Error downloading https://pics.awwmemes.com/whatiwant-to-know-on-how-i-met-your-mother-i-8791345.png: HTTPSConnectionPool(host='pics.awwmemes.com', port=443): Max retries exceeded with url: /whatiwant-to-know-on-how-i-met-your-mother-i-8791345.png (Caused by SSLError(SSLError(1, '[SSL: TLSV1_UNRECOGNIZED_NAME] tlsv1 unrecognized name (_ssl.c:1007)')))
# Downloaded: image_158.jpg
# Downloaded: image_159.jpg
# Downloaded: image_160.jpg
# Downloaded: image_161.jpg
# Downloaded: image_162.jpg
# Downloaded: image_163.jpeg
# Downloaded: image_164.jpg
# Downloaded: image_165.jpg
# Downloaded: image_166.jpg
# Downloaded: image_167.jpg
# Downloaded: image_168.jpg
# Downloaded: image_169.jpeg
# Downloaded: image_170.jpeg
# Downloaded: image_171.jpeg
# Downloaded: image_172.jpg
# Downloaded: image_173.jpg
# Downloaded: image_174.jpg
# Downloaded: image_175.jpg
# Downloaded: image_176.jpeg
# Downloaded: image_177.jpeg
# Downloaded: image_178.jpg
# Downloaded: image_179.jpg
# Downloaded: image_180.jpeg
# Downloaded: image_181.jpg
# Downloaded: image_182.jpg
# Downloaded: image_183.jpg
# Error downloading https://cdn.dopl3r.com/memes_files/almost-had-a-heart-attack-this-morning-at-work-JkDM3.jpg: HTTPSConnectionPool(host='cdn.dopl3r.com', port=443): Max retries exceeded with url: /memes_files/almost-had-a-heart-attack-this-morning-at-work-JkDM3.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a942efdbd30>: Failed to resolve 'cdn.dopl3r.com' ([Errno -5] No address associated with hostname)"))
# Error downloading https://img.memecdn.com/badass-bean_c_3170379.jpg: HTTPSConnectionPool(host='img.memecdn.com', port=443): Max retries exceeded with url: /badass-bean_c_3170379.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a942ed91360>: Failed to resolve 'img.memecdn.com' ([Errno -2] Name or service not known)"))
# Failed to download: https://www.completegate.com/images/meme/mr-bean/bean-extra-class.jpg (Status Code: 406)
# Failed to download: https://www.completegate.com/images/meme/mr-bean/bean-food.jpg (Status Code: 406)
# Downloaded: image_188.jpg
# Downloaded: image_189.jpg
# Error downloading https://images.cdn.circlesix.co/image/1/700/0/uploads/posts/2017/12/c243984dac95800cd2341d830e6f66c4.jpg: HTTPSConnectionPool(host='images.cdn.circlesix.co', port=443): Max retries exceeded with url: /image/1/700/0/uploads/posts/2017/12/c243984dac95800cd2341d830e6f66c4.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a942ed90a60>: Failed to resolve 'images.cdn.circlesix.co' ([Errno -5] No address associated with hostname)"))
# Downloaded: image_191.jpg
# Downloaded: image_192.jpg
# Error downloading https://pics.ballmemes.com/dont-know-why-this-dude-is-names-mrbeans-because-he-13604343.png: HTTPSConnectionPool(host='pics.ballmemes.com', port=443): Max retries exceeded with url: /dont-know-why-this-dude-is-names-mrbeans-because-he-13604343.png (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a942ed92620>: Failed to resolve 'pics.ballmemes.com' ([Errno -2] Name or service not known)"))
# Downloaded: image_194.jpg
# Error downloading https://pics.me.me/everything-photoshopped-with-mr-beans-face-is-so-cool-namue-18223048.png: HTTPSConnectionPool(host='pics.me.me', port=443): Max retries exceeded with url: /everything-photoshopped-with-mr-beans-face-is-so-cool-namue-18223048.png (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a942ed90970>: Failed to resolve 'pics.me.me' ([Errno -2] Name or service not known)"))
# Error downloading https://pics.conservativememes.com/expect-least-from-others-enjoy-your-own-company-lac-laughing-6969117.png: HTTPSConnectionPool(host='pics.conservativememes.com', port=443): Max retries exceeded with url: /expect-least-from-others-enjoy-your-own-company-lac-laughing-6969117.png (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a942efda920>: Failed to resolve 'pics.conservativememes.com' ([Errno -2] Name or service not known)"))
# Error downloading https://pics.onsizzle.com/forrest-edwards-slap-pals-questions-slapsubscribe-subscribed-347-videos-hrashi-1013676.png: HTTPSConnectionPool(host='pics.onsizzle.com', port=443): Max retries exceeded with url: /forrest-edwards-slap-pals-questions-slapsubscribe-subscribed-347-videos-hrashi-1013676.png (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a942efdb820>: Failed to resolve 'pics.onsizzle.com' ([Errno -2] Name or service not known)"))
# Downloaded: image_198.jpg
# Failed to download: http://weknowmemes.com/wp-content/uploads/2012/07/good-guy-mr-bean.jpg (Status Code: 403)
# Failed to download: https://wanna-joke.com/wp-content/uploads/2017/01/green-tea-taste-truth-me-bean.jpg (Status Code: 403)
# Error downloading https://pics.me.me/happy-birthday-rowan-at-oh-sorry-mr-bean-16391224.png: HTTPSConnectionPool(host='pics.me.me', port=443): Max retries exceeded with url: /happy-birthday-rowan-at-oh-sorry-mr-bean-16391224.png (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a942ed92620>: Failed to resolve 'pics.me.me' ([Errno -2] Name or service not known)"))
# Error downloading https://pics.loveforquotes.com/if-there-is-any-character-who-isloved-by-the-entire-6408754.png: HTTPSConnectionPool(host='pics.loveforquotes.com', port=443): Max retries exceeded with url: /if-there-is-any-character-who-isloved-by-the-entire-6408754.png (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a942ed90310>: Failed to resolve 'pics.loveforquotes.com' ([Errno -2] Name or service not known)"))
# Downloaded: image_203.JPG
# Error downloading https://pics.esmemes.com/just-looking-for-a-cunt-mr-bean-memes-oh-hello-20293725.png: HTTPSConnectionPool(host='pics.esmemes.com', port=443): Max retries exceeded with url: /just-looking-for-a-cunt-mr-bean-memes-oh-hello-20293725.png (Caused by SSLError(SSLError(1, '[SSL: TLSV1_UNRECOGNIZED_NAME] tlsv1 unrecognized name (_ssl.c:1007)')))
# Error downloading https://img.memecdn.com/just-mr-bean_o_167403.jpg: HTTPSConnectionPool(host='img.memecdn.com', port=443): Max retries exceeded with url: /just-mr-bean_o_167403.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a942ed932e0>: Failed to resolve 'img.memecdn.com' ([Errno -2] Name or service not known)"))
# Error downloading https://pics.awwmemes.com/ladies-and-gentlemen-its-time-for-mr-bean-memes-the-36492395.png: HTTPSConnectionPool(host='pics.awwmemes.com', port=443): Max retries exceeded with url: /ladies-and-gentlemen-its-time-for-mr-bean-memes-the-36492395.png (Caused by SSLError(SSLError(1, '[SSL: TLSV1_UNRECOGNIZED_NAME] tlsv1 unrecognized name (_ssl.c:1007)')))
# Error downloading https://img.memecdn.com/Ladies-Man-Mr-Bean_o_106097.jpg: HTTPSConnectionPool(host='img.memecdn.com', port=443): Max retries exceeded with url: /Ladies-Man-Mr-Bean_o_106097.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a942efdada0>: Failed to resolve 'img.memecdn.com' ([Errno -2] Name or service not known)"))
# Error downloading https://data.whicdn.com/images/110519765/large.jpg: HTTPSConnectionPool(host='data.whicdn.com', port=443): Max retries exceeded with url: /images/110519765/large.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a942ed91ea0>: Failed to resolve 'data.whicdn.com' ([Errno -2] Name or service not known)"))
# Error downloading https://pics.me.me/like-this-picture-ca-de-if-mr-bean-made-your-8734691.png: HTTPSConnectionPool(host='pics.me.me', port=443): Max retries exceeded with url: /like-this-picture-ca-de-if-mr-bean-made-your-8734691.png (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a942ed915d0>: Failed to resolve 'pics.me.me' ([Errno -2] Name or service not known)"))
# Failed to download: https://sayingimages.com/wp-content/uploads/me-when-my-mom-says-im-handsome-mr-bean-meme.jpeg (Status Code: 404)
# Downloaded: image_211.jpg
# Error downloading https://pics.conservativememes.com/mr-bean-and-dr-house-in-battlefield-1-memeful-com-14025995.png: HTTPSConnectionPool(host='pics.conservativememes.com', port=443): Max retries exceeded with url: /mr-bean-and-dr-house-in-battlefield-1-memeful-com-14025995.png (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a942ed90c40>: Failed to resolve 'pics.conservativememes.com' ([Errno -2] Name or service not known)"))
# Error downloading https://pics.awwmemes.com/mr-bean-asking-foir-likes-how-many-for-this-legend-29498684.png: HTTPSConnectionPool(host='pics.awwmemes.com', port=443): Max retries exceeded with url: /mr-bean-asking-foir-likes-how-many-for-this-legend-29498684.png (Caused by SSLError(SSLError(1, '[SSL: TLSV1_UNRECOGNIZED_NAME] tlsv1 unrecognized name (_ssl.c:1007)')))
# Downloaded: image_214.jpg
# Error downloading https://pics.ballmemes.com/mr-bean-didit-before-it-was-cool-4280098.png: HTTPSConnectionPool(host='pics.ballmemes.com', port=443): Max retries exceeded with url: /mr-bean-didit-before-it-was-cool-4280098.png (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a942efdba30>: Failed to resolve 'pics.ballmemes.com' ([Errno -2] Name or service not known)"))
# Error downloading http://nanoict.org/wp-content/uploads/2018/10/mr-bean-face-imgflip.jpg: HTTPConnectionPool(host='nanoict.org', port=80): Max retries exceeded with url: /wp-content/uploads/2018/10/mr-bean-face-imgflip.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7a942ed903d0>: Failed to resolve 'nanoict.org' ([Errno -2] Name or service not known)"))
# Error downloading https://img.memecdn.com/Mr-Bean-Forever-Alone-Before-it-was-cool_o_97323.jpg: HTTPSConnectionPool(host='img.memecdn.com', port=443): Max retries exceeded with url: /Mr-Bean-Forever-Alone-Before-it-was-cool_o_97323.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x
jpg (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7a942ed93700>: Failed to resolve 'picsmine.com' ([Errno -2] Name or service not known)"))
# Failed to download: https://i0.wp.com/picsmine.com/wp-content/uploads/2017/03/Mr-Bean-Meme-When-mr.bean-gives-you-this-look-you-know-youre.jpg?resize=640%2C510 (Status Code: 400)
# Error downloading https://img.memecdn.com/mr-bean-ms-bean_o_426436.jpg: HTTPSConnectionPool(host='img.memecdn.com', port=443): Max retries exceeded with url: /mr-bean-ms-bean_o_426436.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a942ed93040>: Failed to resolve 'img.memecdn.com' ([Errno -2] Name or service not known)"))
# Error downloading https://img.memecdn.com/mr-bean_o_1909283.jpg: HTTPSConnectionPool(host='img.memecdn.com', port=443): Max retries exceeded with url: /mr-bean_o_1909283.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a942ed91210>: Failed to resolve 'img.memecdn.com' ([Errno -2] Name or service not known)"))
# Downloaded: image_233.png
# Error downloading https://pics.awwmemes.com/mr-beans-daughter-reality-expectations-holyy-his-daughter-is-way-4691633.png: HTTPSConnectionPool(host='pics.awwmemes.com', port=443): Max retries exceeded with url: /mr-beans-daughter-reality-expectations-holyy-his-daughter-is-way-4691633.png (Caused by SSLError(SSLError(1, '[SSL: TLSV1_UNRECOGNIZED_NAME] tlsv1 unrecognized name (_ssl.c:1007)')))
# Error downloading https://pics.ballmemes.com/mr-bean-taught-me-one-thing-in-life-enjoy-your-45766846.png: HTTPSConnectionPool(host='pics.ballmemes.com', port=443): Max retries exceeded with url: /mr-bean-taught-me-one-thing-in-life-enjoy-your-45766846.png (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a942ed90a60>: Failed to resolve 'pics.ballmemes.com' ([Errno -2] Name or service not known)"))
# Error downloading https://pics.awwmemes.com/mr-bean-teddy-indian-still-a-better-love-story-than-14304274.png: HTTPSConnectionPool(host='pics.awwmemes.com', port=443): Max retries exceeded with url: /mr-bean-teddy-indian-still-a-better-love-story-than-14304274.png (Caused by SSLError(SSLError(1, '[SSL: TLSV1_UNRECOGNIZED_NAME] tlsv1 unrecognized name (_ssl.c:1007)')))
# Error downloading https://pics.esmemes.com/mr-bean-the-real-inventor-of-selfies-jude-the-first-20666695.png: HTTPSConnectionPool(host='pics.esmemes.com', port=443): Max retries exceeded with url: /mr-bean-the-real-inventor-of-selfies-jude-the-first-20666695.png (Caused by SSLError(SSLError(1, '[SSL: TLSV1_UNRECOGNIZED_NAME] tlsv1 unrecognized name (_ssl.c:1007)')))
# Failed to download: https://static.fjcdn.com/pictures/Mr+bean+thumb+for+oc_0c2e16_3448404.jpg (Status Code: 404)
# Error downloading https://pics.me.me/mum-but-you-got-paid-last-week-me-idk-what-7909722.png: HTTPSConnectionPool(host='pics.me.me', port=443): Max retries exceeded with url: /mum-but-you-got-paid-last-week-me-idk-what-7909722.png (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a942ed90e20>: Failed to resolve 'pics.me.me' ([Errno -2] Name or service not known)"))
# Error downloading https://pics.conservativememes.com/my-friend-met-the-pakistani-mr-bean-41914456.png: HTTPSConnectionPool(host='pics.conservativememes.com', port=443): Max retries exceeded with url: /my-friend-met-the-pakistani-mr-bean-41914456.png (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x
Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a942edf8f10>: Failed to resolve 'pics.ballmemes.com' ([Errno -2] Name or service not known)"))
# Downloaded: image_2967.jpg
# Downloaded: image_2968.jpg
# Downloaded: image_2969.jpg
# Error downloading https://pics.me.me/people-who-were10-when-finding-nemo-came-out-will-be-23520469.png: HTTPSConnectionPool(host='pics.me.me', port=443): Max retries exceeded with url: /people-who-were10-when-finding-nemo-came-out-will-be-23520469.png (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a942edfb790>: Failed to resolve 'pics.me.me' ([Errno -2] Name or service not known)"))
# Error downloading https://pics.esmemes.com/pixar-just-announced-finding-nemo-3-the-search-of-future-14032651.png: HTTPSConnectionPool(host='pics.esmemes.com', port=443): Max retries exceeded with url: /pixar-just-announced-finding-nemo-3-the-search-of-future-14032651.png (Caused by SSLError(SSLError(1, '[SSL: TLSV1_UNRECOGNIZED_NAME] tlsv1 unrecognized name (_ssl.c:1007)')))
# Failed to download: https://sayingimages.com/wp-content/uploads/sale-nemo-meme.jpg (Status Code: 404)
# Failed to download: https://i.imgur.com/SjiQlbu.png (Status Code: 429)
# Failed to download: https://i.imgur.com/tCZ7wOX.jpg (Status Code: 429)
# Downloaded: image_2975.png
# Error downloading https://pics.esmemes.com/til-andrew-lincoln-was-originally-cast-as-marlin-from-finding-39576645.png: HTTPSConnectionPool(host='pics.esmemes.com', port=443): Max retries exceeded with url: /til-andrew-lincoln-was-originally-cast-as-marlin-from-finding-39576645.png (Caused by SSLError(SSLError(1, '[SSL: TLSV1_UNRECOGNIZED_NAME] tlsv1 unrecognized name (_ssl.c:1007)')))
# Failed to download: https://i.imgur.com/TK6A2Uo.png (Status Code: 429)
# Downloaded: image_2978.jpg
# Downloaded: image_2979.png
# Error downloading https://pics.me.me/when-nobody-is-making-finding-nemo-memes-gerald-intensiftesl-sad-47897883.png: HTTPSConnectionPool(host='pics.me.me', port=443): Max retries exceeded with url: /when-nobody-is-making-finding-nemo-memes-gerald-intensiftesl-sad-47897883.png (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a942edfb340>: Failed to resolve 'pics.me.me' ([Errno -2] Name or service not known)"))
# Error downloading http://jokideo.com/wp-content/uploads/meme/2014/07/When-you-see-it---finding-nemo.jpg: HTTPConnectionPool(host='jokideo.com', port=80): Max retries exceeded with url: /wp-content/uploads/meme/2014/07/When-you-see-it---finding-nemo.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7a942edfbd30>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error downloading https://pics.conservativememes.com/where-is-my-son-i-want-answers-finding-nemo-pt-20865049.png: HTTPSConnectionPool(host='pics.conservativememes.com', port=443): Max retries exceeded with url: /where-is-my-son-i-want-answers-finding-nemo-pt-20865049.png (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a942edfbca0>: Failed to resolve 'pics.conservativememes.com' ([Errno -2] Name or service not known)"))
# Downloaded: image_2983.jpg
# Downloaded: image_2984.jpg
# Downloaded: image_2985.png
# Downloaded: image_2986.jpg
# Downloaded: image_2987.png
# Failed to download: https://cdn.someecards.com/posts/joe-biden-barack-obama-memes-statement-chicago-tribune-BWi.jpg (Status Code: 404)
# Error downloading https://pics.me.me/notion-trump-my-president-deplo-maga-but-hes-alsobarack-obama-20737396.png: HTTPSConnectionPool(host='pics.me.me', port=443): Max retries exceeded with url: /notion-trump-my-president-deplo-maga-but-hes-alsobarack-obama-20737396.png (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a942edfb070>: Failed to resolve 'pics.me.me' ([Errno -2] Name or service not known)"))
# Downloaded: image_2990.jpg
# Downloaded: image_2991.png
# Error downloading http://funnypicturesplus.com/wp-content/uploads/2012/10/obama-romney-meme.jpg: HTTPConnectionPool(host='funnypicturesplus.com', port=80): Max retries exceeded with url: /wp-content/uploads/2012/10/obama-romney-meme.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7a942ed922c0>, 'Connection to funnypicturesplus.com timed out. (connect timeout=10)'))
# Error downloading https://pics.me.me/breaking-news-10-michelle-obama-arrested-in-north-carolinafor-trying-26427164.png: HTTPSConnectionPool(host='pics.me.me', port=443): Max retries exceeded with url: /breaking-news-10-michelle-obama-arrested-in-north-carolinafor-trying-26427164.png (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a942edf8be0>: Failed to resolve 'pics.me.me' ([Errno -2] Name or service not known)"))
# Failed to download: https://cdn3-www.mandatory.com/assets/uploads/2017/05/obama-meme-7.jpg (Status Code: 404)
# Downloaded: image_2995.png
# Failed to download: http://www.funnybeing.com/wp-content/uploads/2017/02/Deal-With-It.jpg (Status Code: 406)
# Downloaded: image_2997.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-7048ad1cc8a6> in <cell line: 21>()
#      25
#      26     try:
# ---> 27         response = requests.get(img_url, stream=True, timeout=10)
#      28         if response.status_code == 200:
#      29             with open(img_path, "wb") as img_file:
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     665
#     666         try:
# --> 667             resp = conn.urlopen(
#     668                 method=request.method,
#     669                 url=url,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     785
#     786             # Make the request on the HTTPConnection object
# --> 787             response = self._make_request(
#     788                 conn,
#     789                 method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     462             # Trigger any extra validation we need to do.
#     463             try:
# --> 464                 self._validate_conn(conn)
#     465             except (SocketTimeout, BaseSSLError) as e:
#     466                 self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1091         # Force connect early to allow us to validate the connection.
#    1092         if conn.is_closed:
# -> 1093             conn.connect()
#    1094
#    1095         # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in connect(self)
#     702         try:
#     703             sock: socket.socket | ssl.SSLSocket
# --> 704             self.sock = sock = self._new_conn()
#     705             server_hostname: str = self.host
#     706             tls_in_tls = False
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in _new_conn(self)
#     196         """
#     197         try:
# --> 198             sock = connection.create_connection(
#     199                 (self._dns_host, self.port),
#     200                 self.timeout,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      71             if source_address:
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             # Break explicitly a reference cycle
#      75             err = None
#
# KeyboardInterrupt:

# %%
import os
import re

# Specify the directory path
directory_path = '/kaggle/working/train_images'

# Initialize an empty list to store the numbers
numbers = []

# Iterate over the files in the directory
for filename in os.listdir(directory_path):
    # Use regular expression to extract the number from the filename
    match = re.search(r'(\d+)', filename)
    if match:
        # Append the extracted number to the list
        numbers.append(int(match.group(1)))

# %%
indx = [n-1 for n in numbers]

# %%
import pandas as pd
df = pd.read_csv('/kaggle/input/sentiment-analysis/labels.csv')

# %%
df = df.iloc[indx]
df = df.drop('Unnamed: 0', axis = 1)
df.to_csv('/kaggle/working/train.csv', index=False)

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize label encoders for categorical variables
sentiment_encoder = LabelEncoder()
humor_encoder = LabelEncoder()
sarcasm_encoder = LabelEncoder()
offensive_encoder = LabelEncoder()
motivational_encoder = LabelEncoder()

# Load and preprocess the data
df = pd.read_csv('/kaggle/working/train.csv')

# Encode categorical variables
df['overall_sentiment'] = sentiment_encoder.fit_transform(df['overall_sentiment'])
df['humour'] = humor_encoder.fit_transform(df['humour'])
df['sarcasm'] = sarcasm_encoder.fit_transform(df['sarcasm'])
df['offensive'] = offensive_encoder.fit_transform(df['offensive'])
df['motivational'] = motivational_encoder.fit_transform(df['motivational'])

# %%
df.head()
# Out:
#        image_name                                           text_ocr  \
# 0   image_727.jpg       You didn't cry when Bambi's mother died? Yes
# 1  image_1206.jpg  Carry yourself w/the confidence of a girl hold...
# 2   image_161.jpg                       WHAAAAAAAAT IWASNT LISTENING
# 3  image_1237.png  me after taking one feminist theory class Amen...
# 4   image_188.jpg                        OH SHIT THINK MY WUDU BROKE
#
#                                       text_corrected  humour  sarcasm  \
# 0  You didn't cry when Bambi's mother died? Yes  ...       2        0
# 1  Carry yourself w/the confidence of a girl hold...       3        0
# 2                       WHAAAAAAAAT IWASNT LISTENING       3        2
# 3  me after taking one feminist theory class Amen...       3        1
# 4                        OH SHIT THINK MY WUDU BROKE       2        1
#
#    offensive  motivational  overall_sentiment
# 0          1             0                  1
# 1          3             0                  2
# 2          2             1                  2
# 3          0             0                  1
# 4          1             1                  4

# %%
## import torch
import torch.nn as nn
from transformers import BertTokenizer, BertModel
from torchvision import models, transforms
from torch.utils.data import Dataset, DataLoader
import pandas as pd
from PIL import Image, UnidentifiedImageError


from PIL import Image

class MemeDataset(Dataset):
    def __init__(self, df, img_dir, transform=None):
        self.df = df
        self.img_dir = img_dir
        self.transform = transform
        self.tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        img_name = self.df.iloc[idx]['image_name']
        img_path = os.path.join(self.img_dir, img_name)
        
        try:
            image = Image.open(img_path).convert('RGB')
        except Exception as e:
            print(f"Error loading image {img_name}: {e}")
            # Return a blank image if the file can't be loaded
            image = Image.new('RGB', (224, 224), color='black')

        text = self.df.iloc[idx]['text_corrected']
        
        if self.transform:
            image = self.transform(image)
        
        inputs = self.tokenizer.encode_plus(
            text,
            None,
            add_special_tokens=True,
            max_length=MAX_LEN,
            padding='max_length',
            return_token_type_ids=True,
            truncation=True
        )
        
        ids = inputs['input_ids']
        mask = inputs['attention_mask']
        
        return {
            'ids': torch.tensor(ids, dtype=torch.long),
            'mask': torch.tensor(mask, dtype=torch.long),
            'image': image,
            'sentiment': torch.tensor(self.df.iloc[idx]['overall_sentiment'], dtype=torch.long),
            'humor': torch.tensor(self.df.iloc[idx]['humour'], dtype=torch.float),
            'sarcasm': torch.tensor(self.df.iloc[idx]['sarcasm'], dtype=torch.float),
            'offensive': torch.tensor(self.df.iloc[idx]['offensive'], dtype=torch.float),
            'motivational': torch.tensor(self.df.iloc[idx]['motivational'], dtype=torch.float)
        }



# Model Architecture
class MemeAnalysisModel(nn.Module):
    def __init__(self):
        super(MemeAnalysisModel, self).__init__()
        self.bert = BertModel.from_pretrained('bert-base-uncased')
        self.resnet = models.resnet50(pretrained=True)
        self.resnet.fc = nn.Identity()  # Remove the final fully connected layer
        
        self.fusion = nn.Linear(768 + 2048, 512)
        self.dropout = nn.Dropout(0.1)
        
        # Task-specific layers
        self.sentiment_classifier = nn.Linear(512, 5)  
        self.humor_classifier = nn.Linear(512, 4)
        self.sarcasm_classifier = nn.Linear(512, 4)
        self.offensive_classifier = nn.Linear(512, 4)
        self.motivational_classifier = nn.Linear(512, 2)
        
        # Regression heads for scales
        self.humor_scale = nn.Linear(512, 1)
        self.sarcasm_scale = nn.Linear(512, 1)
        self.offensive_scale = nn.Linear(512, 1)
        self.motivational_scale = nn.Linear(512, 1)

    def forward(self, input_ids, attention_mask, image):
        text_output = self.bert(input_ids=input_ids, attention_mask=attention_mask)
        text_features = text_output.pooler_output
        
        image_features = self.resnet(image)
        
        combined = torch.cat((text_features, image_features), dim=1)
        fused = self.fusion(combined)
        fused = self.dropout(fused)
        
        sentiment = self.sentiment_classifier(fused)
        humor = self.humor_classifier(fused)
        sarcasm = self.sarcasm_classifier(fused)
        offensive = self.offensive_classifier(fused)
        motivational = self.motivational_classifier(fused)
        
        humor_scale = self.humor_scale(fused)
        sarcasm_scale = self.sarcasm_scale(fused)
        offensive_scale = self.offensive_scale(fused)
        motivational_scale = self.motivational_scale(fused)
        
        return sentiment, humor, sarcasm, offensive, motivational, humor_scale, sarcasm_scale, offensive_scale, motivational_scale

# %%
# Constants
MAX_LEN = 128
BATCH_SIZE = 32
LEARNING_RATE = 1e-5
NUM_EPOCHS = 3

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Data Loading
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

train_dataset = MemeDataset(df, img_dir='/kaggle/working/train_images', transform=transform)
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %%
import torch
# Model, Loss, and Optimizer
model = MemeAnalysisModel().to(device)
criterion = nn.CrossEntropyLoss()
mse_loss = nn.MSELoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE)

# Training Loop
for epoch in range(NUM_EPOCHS):
    model.train()
    for batch in train_loader:
        ids = batch['ids'].to(device)
        mask = batch['mask'].to(device)
        image = batch['image'].to(device)
        sentiment = batch['sentiment'].to(device)
        humor = batch['humor'].to(device)
        sarcasm = batch['sarcasm'].to(device)
        offensive = batch['offensive'].to(device)
        motivational = batch['motivational'].to(device)
        
        outputs = model(ids, mask, image)
        
        sentiment_loss = criterion(outputs[0], sentiment)
        humor_loss = mse_loss(outputs[1].squeeze(), humor)
        sarcasm_loss = mse_loss(outputs[2].squeeze(), sarcasm)
        offensive_loss = mse_loss(outputs[3].squeeze(), offensive)
        motivational_loss = mse_loss(outputs[4].squeeze(), motivational)
        
        scale_losses = sum(mse_loss(output.squeeze(), target) for output, target in zip(outputs[5:], [humor, sarcasm, offensive, motivational]))
        
        total_loss = sentiment_loss + humor_loss + sarcasm_loss + offensive_loss + motivational_loss + scale_losses
        
        optimizer.zero_grad()
        total_loss.backward()
        optimizer.step()

        print(f'Epoch [{epoch+1}/{NUM_EPOCHS}], Loss: {total_loss.item():.4f}')
# Out:
# Epoch [1/10], Loss: 1.0165
# Epoch [2/10], Loss: 0.7177
# Epoch [3/10], Loss: 0.5012
# Epoch [4/10], Loss: 0.3594
# Epoch [5/10], Loss: 0.2645
# Epoch [6/10], Loss: 0.1897
# Epoch [7/10], Loss: 0.1430
# Epoch [8/10], Loss: 0.1076
# Epoch [9/10], Loss: 0.0619
# Epoch [10/10], Loss: 0.0501

# %%
# Assuming you have a validation dataloader called 'validation_loader'
model.eval()  # Set the model to evaluation mode
all_predictions = []
all_labels = []

with torch.no_grad():  # Disable gradient calculation during validation
    for batch in validation_loader:
        ids = batch['ids'].to(device)
        mask = batch['mask'].to(device)
        image = batch['image'].to(device)
        labels = batch['sentiment'].to(device)  # Assuming 'sentiment' is the name of your label

        outputs = model(ids, mask, image)  # Make predictions

        #outputs[0] is the sentiment output in the model from previous code

        all_predictions.append(outputs[0].cpu())  # Move to CPU for processing
        all_labels.append(labels.cpu())


all_predictions = torch.cat(all_predictions, dim=0)
all_labels = torch.cat(all_labels, dim=0)


num_classes = 5  # Replace with the actual number of classes
class_accuracies = calculate_class_accuracy(all_predictions, all_labels, num_classes)

print("Class Accuracies:")
for class_label, accuracy in class_accuracies.items():
    print(f"{class_label}: {accuracy:.4f}")
# Out:
# Class Accuracies:
# humour: 0.9654
# sarcasm: 0.9233
# offensive: 0.9563
# motivational: 0.9672
# overall_sentiment: 0.9505
